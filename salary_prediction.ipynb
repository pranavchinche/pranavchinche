# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavchinche/pranavchinche/blob/main/salary_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv")

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
df.shape
# Out:
# (40, 2)

# %%
x=df[["Experience Years"]]
y=df["Salary"]

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)*100
# Out:
# 96.43333811854808

# %%
year=float(input("enter your experience year"))
# Out:
# enter your experience year23

# %%
lr.intercept_
# Out:
# np.float64(26716.250176145535)

# %%
lr.coef_
# Out:
# array([9408.03127251])

# %%
lr.predict([[1.2]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([38005.88770315])

# %%
plt.figure(figure=(10,3))
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red')
plt.xlabel('Experiance Years')
plt.ylabel('Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5630/1283282734.py in <cell line: 0>()
# ----> 1 plt.figure(figure=(10,3))
#       2 plt.scatter(x,y)
#       3 plt.plot(x,lr.predict(x),color='red')
#       4 plt.xlabel('Experiance Years')
#       5 plt.ylabel('Salary')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1040                 RuntimeWarning)
#    1041
# -> 1042         manager = new_figure_manager(
#    1043             num, figsize=figsize, dpi=dpi,
#    1044             facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     550     """Create a new figure manager instance."""
#     551     _warn_if_gui_out_of_main_thread()
# ...
